# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Area codes with å, ä, ö to population data
#
# **Don't run this section (two cells below) if you are using data that already includes these!**
#
# Also, check that the file to be read exists.

# %%
# population_df = pd.read_csv('../data/population_df.csv')

# # Join municipality, code and name to form area code, add prefix 0
# population_df['Area no-dots'] = '0' + population_df['municipality'].astype(str) + " " + population_df['code'].astype(str) + " " + population_df['name']

# # Get original area names with letters å, ä, ö:
# # Fetch district data
# districts = pd.read_csv('../data/Helsinki_districts.csv')
# districts = districts[districts['BASIC'] != 0]
# districts = districts[['Helsinki statistical area code', 'Helsinki statistical area code 2']]
# # Change 091 801 Ostersundomin peruspiiri to 091 801 ostersundomin peruspiiri
# districts['Helsinki statistical area code 2'] = districts['Helsinki statistical area code 2'].str.replace('091 801 Ostersundomin peruspiiri', '091 801 ostersundomin peruspiiri') 

# # Merge district names with letters å, ä, ö to population_df
# population_df = pd.merge(left=population_df, right=districts, how='left', left_on='Area no-dots', right_on='Helsinki statistical area code 2')
# population_df = population_df.drop('Helsinki statistical area code 2', axis=1)
# population_df['Helsinki statistical area code'] = population_df['Helsinki statistical area code'].fillna(population_df['Area no-dots'])
# population_df = population_df.rename(columns={'Helsinki statistical area code': 'Area'})

# population_df.tail(20)
# Out:
#      Gender  \
# 348       0
# 349       1
# 350       0
# 351       1
# 352       0
# 353       1
# 354       0
# 355       1
# 356       0
# 357       1
# 358       0
# 359       1
# 360       0
# 361       1
# 362       0
# 363       1
# 364       0
# 365       1
# 366       0
# 367       1
#
#      Education % 15-24 years Second degree and special vocational training degree  \
# 348                                           0.042404
# 349                                           0.043717
# 350                                           0.041322
# 351                                           0.038050
# 352                                           0.044475
# 353                                           0.047075
# 354                                           0.041348
# 355                                           0.039584
# 356                                           0.050352
# 357                                           0.054640
# 358                                           0.072519
# 359                                           0.049731
# 360                                           0.050000
# 361                                           0.042453
# 362                                           0.045941
# 363                                           0.046091
# 364                                           0.068623
# 365                                           0.088223
# 366                                           0.039430
# 367                                           0.086763
#
#      Education % 15-24 years Lowest higher and lower university level  \
# 348                                           0.002298
# 349                                           0.004144
# 350                                           0.002558
# 351                                           0.003080
# 352                                           0.002073
# 353                                           0.003674
# 354                                           0.001876
# 355                                           0.003713
# 356                                           0.008560
# 357                                           0.007806
# 358                                           0.000000
# 359                                           0.002688
# 360                                           0.000000
# 361                                           0.009434
# 362                                           0.003424
# 363                                           0.006647
# 364                                           0.009455
# 365                                           0.017459
# 366                                           0.002767
# 367                                           0.011123
#
#      Education % 15-24 years Higher university degree and research training  \
# 348                                           0.000000
# 349                                           0.000311
# 350                                           0.000000
# 351                                           0.000000
# 352                                           0.000126
# 353                                           0.000230
# 354                                           0.000134
# 355                                           0.000114
# 356                                           0.000504
# 357                                           0.000434
# 358                                           0.000000
# 359                                           0.000000
# 360                                           0.000000
# 361                                           0.000000
# 362                                           0.000199
# 363                                           0.000399
# 364                                           0.000423
# 365                                           0.001057
# 366                                           0.000000
# 367                                           0.000000
#
#      Education % 15-24 years All levels of education  \
# 348                                         0.128936
# 349                                         0.117062
# 350                                         0.120622
# 351                                         0.103280
# 352                                         0.134682
# 353                                         0.127619
# 354                                         0.129272
# 355                                         0.110641
# 356                                         0.116818
# 357                                         0.109714
# 358                                         0.189567
# 359                                         0.165323
# 360                                         0.120000
# 361                                         0.108491
# 362                                         0.124748
# 363                                         0.113049
# 364                                         0.122246
# 365                                         0.147080
# 366                                         0.142225
# 367                                         0.212681
#
#      Education % 15-24 years Elementary or unknown  \
# 348                                       0.084234
# 349                                       0.068890
# 350                                       0.076741
# 351                                       0.062149
# 352                                       0.088008
# 353                                       0.076640
# 354                                       0.085913
# 355                                       0.067230
# 356                                       0.057402
# 357                                       0.046834
# 358                                       0.117048
# 359                                       0.112903
# 360                                       0.070000
# 361                                       0.056604
# 362                                       0.075183
# 363                                       0.059912
# 364                                       0.043744
# 365                                       0.040342
# 366                                       0.100028
# 367                                       0.114794
#
#      Education % 15-24 years Total graduates  \
# 348                                 0.044702
# 349                                 0.048172
# 350                                 0.043880
# 351                                 0.041131
# 352                                 0.046674
# 353                                 0.050979
# 354                                 0.043359
# 355                                 0.043411
# 356                                 0.059416
# 357                                 0.062879
# 358                                 0.072519
# 359                                 0.052419
# 360                                 0.050000
# 361                                 0.051887
# 362                                 0.049565
# 363                                 0.053136
# 364                                 0.078502
# 365                                 0.106738
# 366                                 0.042197
# 367                                 0.097887
#
#      Education % 25-44 years Second degree and special vocational training degree  \
# 348                                           0.129970
# 349                                           0.094789
# 350                                           0.146989
# 351                                           0.112158
# 352                                           0.152836
# 353                                           0.127906
# 354                                           0.134700
# 355                                           0.107386
# 356                                           0.105740
# 357                                           0.062446
# 358                                           0.055980
# 359                                           0.063172
# 360                                           0.055000
# 361                                           0.051887
# 362                                           0.139202
# 363                                           0.101443
# 364                                           0.148989
# 365                                           0.100800
# 366                                           0.148727
# 367                                           0.113459
#
#      Education % 25-44 years Lowest higher and lower university level  \
# 348                                           0.057688
# 349                                           0.075831
# 350                                           0.064345
# 351                                           0.077188
# 352                                           0.047239
# 353                                           0.058614
# 354                                           0.057566
# 355                                           0.072657
# 356                                           0.079557
# 357                                           0.088899
# 358                                           0.043257
# 359                                           0.049731
# 360                                           0.030000
# 361                                           0.033019
# 362                                           0.079563
# 363                                           0.095361
# 364                                           0.112253
# 365                                           0.129216
# 366                                           0.036386
# 367                                           0.066741
#
#      Education % 25-44 years Higher university degree and research training  \
# 348                                           0.053781
# 349                                           0.074381
# 350                                           0.061196
# 351                                           0.078094
# 352                                           0.030718
# 353                                           0.036856
# 354                                           0.047782
# 355                                           0.058377
# 356                                           0.108761
# 357                                           0.122290
# 358                                           0.030534
# 359                                           0.055108
# 360                                           0.075000
# 361                                           0.099057
# 362                                           0.082987
# 363                                           0.100946
# 364                                           0.144381
# 365                                           0.164055
# 366                                           0.039568
# 367                                           0.084538
#
#      ...  Married couple and children  Unmarried couple without children  \
# 348  ...                     0.280322                           0.156284
# 349  ...                     0.280322                           0.156284
# 350  ...                     0.270795                           0.156648
# 351  ...                     0.270795                           0.156648
# 359  091 801 ostersundomin peruspiiri  091 801 Östersundomin peruspiiri
# 360                091 90 Kaivopuisto                091 90 Kaivopuisto
# 361                091 90 Kaivopuisto                091 90 Kaivopuisto
# 362              091 997 Esikaupungit              091 997 Esikaupungit
# 363              091 997 Esikaupungit              091 997 Esikaupungit
# 364             091 998 Kantakaupunki             091 998 Kantakaupunki
# 365             091 998 Kantakaupunki             091 998 Kantakaupunki
# 366                      091 999 Muut                      091 999 Muut
# 367                      091 999 Muut                      091 999 Muut
#
# [20 rows x 45 columns]

# %%
# # Save to file population_df2.csv
# population_df.to_csv('../data/population_df2.csv', index=False)

# %% [markdown]
# ## Data for one-person households

# %%
# Fetch data from file in folder 'data'
ones = pd.read_csv('../data/Helsinki_oneperson_households.csv')
ones
# Out:
#    One-person hh, Gender  One-person hh, All ages  One-person hh, Age -19  \
# 0                    Men                     1306                      18
# 1                  Women                     1925                      31
# 2                    Men                     3117                      28
# 3                  Women                     4575                      92
# 4                    Men                     5299                      77
# ..                   ...                      ...                     ...
# 63                 Women                     5505                      86
# 64                   Men                     3968                      38
# 65                 Women                     5606                      49
# 66                   Men                       68                       1
# 67                 Women                       45                       0
#
#     One-person hh, Age 20-29  One-person hh, Age 30-39  \
# 0                        293                       248
# 1                        428                       230
# 2                        847                       647
# 3                       1254                       759
# 4                       1598                      1238
# ..                       ...                       ...
# 63                       623                       421
# 64                       592                       754
# 65                       556                       439
# 66                         2                         7
# 67                         2                         2
#
#     One-person hh, Age 40-49  One-person hh, Age 50-59  \
# 0                      210.0                       195
# 1                      161.0                       213
# 2                      517.0                       427
# 3                      379.0                       481
# 4                      795.0                       661
# ..                       ...                       ...
# 63                     358.0                       856
# 64                     617.0                       797
# 65                     426.0                       986
# 66                      11.0                        16
# 67                       6.0                        10
#
#     One-person hh, Age 60-64  One-person hh, Age 65-69  \
# 0                         80                        67
# 1                        106                       159
# 2                        191                       132
# 3                        278                       298
# 4                        278                       178
# ..                       ...                       ...
# 63                       594                       571
# 64                       348                       254
# 65                       544                       557
# 66                         7                         6
# 67                         5                         3
#
#     One-person hh, Age 70-74  One-person hh, Age 75-79  \
# 0                         76                        53
# 1                        174                       168
# 2                        109                        84
# 3                        314                       310
# 4                        162                       162
# ..                       ...                       ...
# 63                       562                       519
# 64                       188                       159
# 65                       617                       518
# 66                         5                         7
# 67                         4                         4
#
#     One-person hh, Age 80-84  One-person hh, Age 85  \
# 0                         43                     23
# 1                        135                    120
# 2                         70                     65
# 3                        210                    200
# 4                         69                     81
# ..                       ...                    ...
# 63                       452                    463
# 64                       113                    108
# 65                       467                    447
# 66                         3                      3
# 67                         5                      4
#
#    One-person hh, Major district One-person hh, District
# 0          1 Eteläinen suurpiiri          101 Vironniemi
# 1          1 Eteläinen suurpiiri          101 Vironniemi
# 2          1 Eteläinen suurpiiri          102 Ullanlinna
# 3          1 Eteläinen suurpiiri          102 Ullanlinna
# 4          1 Eteläinen suurpiiri         103 Kampinmalmi
# ..                           ...                     ...
# 63           7 Itäinen suurpiiri          703 Mellunkylä
# 64           7 Itäinen suurpiiri            704 Vuosaari
# 65           7 Itäinen suurpiiri            704 Vuosaari
# 66     8 Östersundomin suurpiiri         801 Östersundom
# 67     8 Östersundomin suurpiiri         801 Östersundom
#
# [68 rows x 15 columns]

# %%
# Get data for total population per gender per district

# Fetch data of all population per district
allpeople = pd.read_csv('../data/Helsingin_vaesto_sukupuolen_ian_ja_aidinkielen_ruotsinkieliset_mukaan.csv',
                       encoding='ISO-8859-1')

# Remove rows that include total data for both genders ('Molemmat sukupuolet')
allpeople = allpeople[allpeople['Sukupuoli'] != 'Molemmat sukupuolet']
# Keep only needed columns
allpeople = allpeople[['Alue', 'Sukupuoli', 'Väestö yhteensä 2022']]
# Replace missing population information '..' with NaN
allpeople['Väestö yhteensä 2022'] = allpeople['Väestö yhteensä 2022'].replace('..', np.nan)


# Fetch district data and convert to same format as in one-person household data
distr = pd.read_csv('../data/Helsinki_districts.csv')
distr = distr[distr['BASIC'] != 0]

distr[['City code', 'District code', 'District level name']] = distr['Helsinki statistical area code'].str.split(' ', n=2, expand=True)
distr['District'] = distr['District code'] + " " + distr['Name']
distr = distr[['Helsinki statistical area code', 'District']]


# Join district code & name with allpeople
people = pd.merge(left=allpeople, right=distr, how='inner', left_on='Alue', right_on='Helsinki statistical area code')
people = people[['Sukupuoli', 'Väestö yhteensä 2022', 'District', 'Alue']]
people.columns = ['Gender', 'Population', 'District', 'District long code']
people['Gender'] = people['Gender'].replace({'Miehet': 'Men', 'Naiset': 'Women'})

people.head(10)
# Out:
#   Gender Population        District              District long code
# 0    Men       6064  101 Vironniemi  091 101 Vironniemen peruspiiri
# 1  Women       6920  101 Vironniemi  091 101 Vironniemen peruspiiri
# 2    Men       3355  10 Kruununhaka              091 10 Kruununhaka
# 3  Women       3867  10 Kruununhaka              091 10 Kruununhaka
# 4    Men        351       20 Kluuvi                   091 20 Kluuvi
# 5  Women        315       20 Kluuvi                   091 20 Kluuvi
# 6    Men       2358  80 Katajanokka              091 80 Katajanokka
# 7  Women       2738  80 Katajanokka              091 80 Katajanokka
# 8    Men      11283  102 Ullanlinna  091 102 Ullanlinnan peruspiiri
# 9  Women      13091  102 Ullanlinna  091 102 Ullanlinnan peruspiiri

# %%
# Join total population data with one-person household data
ones2 = pd.merge(left=ones, right=people, how='inner', left_on=['One-person hh, District', 'One-person hh, Gender'], right_on=['District', 'Gender'])
ones2 = ones2.drop(['One-person hh, District', 'One-person hh, Gender', 'One-person hh, Major district'], axis=1)
ones2['Population'] = ones2['Population'].apply(pd.to_numeric)
ones2
# Out:
#     One-person hh, All ages  One-person hh, Age -19  One-person hh, Age 20-29  \
# 0                      1306                      18                       293
# 1                      1925                      31                       428
# 2                      3117                      28                       847
# 3                      4575                      92                      1254
# 4                      5299                      77                      1598
# ..                      ...                     ...                       ...
# 63                     5505                      86                       623
# 64                     3968                      38                       592
# 65                     5606                      49                       556
# 66                       68                       1                         2
# 67                       45                       0                         2
#
#     One-person hh, Age 30-39  One-person hh, Age 40-49  \
# 0                        248                     210.0
# 1                        230                     161.0
# 2                        647                     517.0
# 3                        759                     379.0
# 4                       1238                     795.0
# ..                       ...                       ...
# 63                       421                     358.0
# 64                       754                     617.0
# 65                       439                     426.0
# 66                         7                      11.0
# 67                         2                       6.0
#
#     One-person hh, Age 50-59  One-person hh, Age 60-64  \
# 0                        195                        80
# 1                        213                       106
# 2                        427                       191
# 3                        481                       278
# 4                        661                       278
# ..                       ...                       ...
# 63                       856                       594
# 64                       797                       348
# 65                       986                       544
# 66                        16                         7
# 67                        10                         5
#
#     One-person hh, Age 65-69  One-person hh, Age 70-74  \
# 0                         67                        76
# 1                        159                       174
# 2                        132                       109
# 3                        298                       314
# 4                        178                       162
# ..                       ...                       ...
# 63                       571                       562
# 64                       254                       188
# 65                       557                       617
# 66                         6                         5
# 67                         3                         4
#
#     One-person hh, Age 75-79  One-person hh, Age 80-84  One-person hh, Age 85  \
# 0                         53                        43                     23
# 1                        168                       135                    120
# 2                         84                        70                     65
# 3                        310                       210                    200
# 4                        162                        69                     81
# ..                       ...                       ...                    ...
# 63                       519                       452                    463
# 64                       159                       113                    108
# 65                       518                       467                    447
# 66                         7                         3                      3
# 67                         4                         5                      4
#
#    Gender  Population         District                District long code
# 0     Men        6064   101 Vironniemi    091 101 Vironniemen peruspiiri
# 1   Women        6920   101 Vironniemi    091 101 Vironniemen peruspiiri
# 2     Men       11283   102 Ullanlinna    091 102 Ullanlinnan peruspiiri
# 3   Women       13091   102 Ullanlinna    091 102 Ullanlinnan peruspiiri
# 4     Men       21160  103 Kampinmalmi   091 103 Kampinmalmin peruspiiri
# ..    ...         ...              ...                               ...
# 63  Women       20436   703 Mellunkylä    091 703 Mellunkylän peruspiiri
# 64    Men       18248     704 Vuosaari      091 704 Vuosaaren peruspiiri
# 65  Women       20542     704 Vuosaari      091 704 Vuosaaren peruspiiri
# 66    Men         908  801 Östersundom  091 801 Östersundomin peruspiiri
# 67  Women         877  801 Östersundom  091 801 Östersundomin peruspiiri
#
# [68 rows x 16 columns]

# %%
# Change the age specific columns from amounts to portions of total population

ones_portions = ones2.copy()

# Divide amounts of people in each one-person hh column by total population in district
# and add suffix '%'' to column names to indicate portions
cols_include = ones_portions.columns[~ones_portions.columns.isin(['Gender', 'Population', 'District', 'District long code'])]
for col in cols_include:
    ones_portions[col] = ones2[col].div(ones2['Population'], axis=0)
    ones_portions.rename(columns={col: col+', %'}, inplace=True)

# Merge with sub-district-level population data
ones_portions = pd.merge(left=ones_portions, right=people, how='right', 
                         left_on=['District', 'Gender'], right_on=['District', 'Gender'])
ones_portions = ones_portions.drop(['Population_x', 'District'], axis=1)
ones_portions = ones_portions.rename(columns={'District long code_x': 'District',
                                              'District long code_y': 'Area',
                                              'Population_y' : 'Population'})

# Fill down district-level name
ones_portions['District'] = ones_portions['District'].ffill()


# Copy rows where population is missing
no_pop = ones_portions[ones_portions['Population'].isna()]

# Remove the rows from ones_portions 
ones_portions = ones_portions[~ones_portions['Population'].isna()]

# Sort rows based on District, Gender and All ages
ones_portions = ones_portions.sort_values(by = ['District', 'Gender', 'One-person hh, All ages, %'], ascending = [True, True, False])
 
# Fill down values in portions columns to sub-district level
ones_portions = ones_portions.ffill()

# Append no-population rows back to population data
ones_portions =  pd.concat([ones_portions, no_pop])

# remove columns District and Population
ones_portions = ones_portions.drop(['District', 'Population'], axis=1)


# Change gender to categorical type
ones_portions['Gender'] = ones_portions['Gender'].map({'Men':0, 'Women':1})
ones_portions['Gender'] = ones_portions['Gender'].astype('category') 


# Sort along index
ones_portions.sort_index(inplace=True)


ones_portions
# Out:
#      One-person hh, All ages, %  One-person hh, Age -19, %  \
# 0                      0.215369                   0.002968
# 1                      0.278179                   0.004480
# 2                      0.215369                   0.002968
# 3                      0.278179                   0.004480
# 4                      0.215369                   0.002968
# ..                          ...                        ...
# 357                    0.051311                   0.000000
# 358                    0.074890                   0.001101
# 359                    0.051311                   0.000000
# 360                    0.074890                   0.001101
# 361                    0.051311                   0.000000
#
#      One-person hh, Age 20-29, %  One-person hh, Age 30-39, %  \
# 0                       0.048318                     0.040897
# 1                       0.061850                     0.033237
# 2                       0.048318                     0.040897
# 3                       0.061850                     0.033237
# 4                       0.048318                     0.040897
# ..                           ...                          ...
# 357                     0.002281                     0.002281
# 358                     0.002203                     0.007709
# 359                     0.002281                     0.002281
# 360                     0.002203                     0.007709
# 361                     0.002281                     0.002281
#
#      One-person hh, Age 40-49, %  One-person hh, Age 50-59, %  \
# 0                       0.034631                     0.032157
# 1                       0.023266                     0.030780
# 2                       0.034631                     0.032157
# 3                       0.023266                     0.030780
# 4                       0.034631                     0.032157
# ..                           ...                          ...
# 357                     0.006842                     0.011403
# 358                     0.012115                     0.017621
# 359                     0.006842                     0.011403
# 360                     0.012115                     0.017621
# 361                     0.006842                     0.011403
#
#      One-person hh, Age 60-64, %  One-person hh, Age 65-69, %  \
# 0                       0.013193                     0.011049
# 1                       0.015318                     0.022977
# 2                       0.013193                     0.011049
# 3                       0.015318                     0.022977
# 4                       0.013193                     0.011049
# ..                           ...                          ...
# 357                     0.005701                     0.003421
# 358                     0.007709                     0.006608
# 359                     0.005701                     0.003421
# 360                     0.007709                     0.006608
# 361                     0.005701                     0.003421
#
#      One-person hh, Age 70-74, %  One-person hh, Age 75-79, %  \
# 0                       0.012533                     0.008740
# 1                       0.025145                     0.024277
# 2                       0.012533                     0.008740
# 3                       0.025145                     0.024277
# 4                       0.012533                     0.008740
# ..                           ...                          ...
# 357                     0.004561                     0.004561
# 358                     0.005507                     0.007709
# 359                     0.004561                     0.004561
# 360                     0.005507                     0.007709
# 361                     0.004561                     0.004561
#
#      One-person hh, Age 80-84, %  One-person hh, Age 85, % Gender  \
# 0                       0.007091                  0.003793      0
# 1                       0.019509                  0.017341      1
# 2                       0.007091                  0.003793      0
# 3                       0.019509                  0.017341      1
# 4                       0.007091                  0.003793      0
# ..                           ...                       ...    ...
# 357                     0.005701                  0.004561      1
# 358                     0.003304                  0.003304      0
# 359                     0.005701                  0.004561      1
# 360                     0.003304                  0.003304      0
# 361                     0.005701                  0.004561      1
#
#                                Area
# 0    091 101 Vironniemen peruspiiri
# 1    091 101 Vironniemen peruspiiri
# 2                091 10 Kruununhaka
# 3                091 10 Kruununhaka
# 4                     091 20 Kluuvi
# ..                              ...
# 357              091 580 Karhusaari
# 358                  091 591 Landbo
# 359                  091 591 Landbo
# 360              091 592 Puroniitty
# 361              091 592 Puroniitty
#
# [362 rows x 14 columns]

# %% [markdown]
# ## Data for morbidity index

# %%
# Latest published data is from 2021 but we will make an assumption that the indices are the same in 2022.
# Indices for the whole city is 100. 

# Read data and drop unneeded columns
morb_fetch = pd.read_csv('../data/Helsinki_morbidity_index.csv')
morb_fetch = morb_fetch.drop(['Morbidity, Population', 'Morbidity, Major district'], axis=1)

morb_fetch.head()
# Out:
#   Morbidity, District  Morbidity, Morbidity index  Morbidity, Mortality index  \
# 0          Vironniemi                   67.586539                   69.787493
# 1          Ullanlinna                   65.665101                   73.060317
# 2         Kampinmalmi                   82.818148                   74.817956
# 3          Taka-Töölö                   87.902482                   95.685431
# 4         Lauttasaari                   70.974337                   72.153629
#
#    Morbidity, Disability pension index  \
# 0                            47.104700
# 1                            43.092436
# 2                            78.870986
# 3                            78.013245
# 4                            51.920147
#
#    Morbidity, Medicine reimbursement index  Morbidity, Chronic diseases index
# 0                                85.867423                          76.318461
# 1                                80.842549                          67.995023
# 2                                94.765503                          88.586840
# 3                                90.008771                          85.981219
# 4                                88.849234                          76.159888

# %%
# Merge morbidity data with district codes 

# Fetch district data
distr = pd.read_csv('../data/Helsinki_districts.csv')
distr = distr[distr['BASIC'] != 0]
distr = distr[['Helsinki statistical area code', 'District']]

# Join districts and morbidity data
morb = pd.merge(left=distr, right=morb_fetch, how='left', left_on='District', right_on='Morbidity, District')

# Rename
morb = morb.rename(columns={'Helsinki statistical area code': 'Area'})
morb = morb.drop(['District', 'Morbidity, District'], axis=1)

morb.head(50)
# Out:
#                                Area  Morbidity, Morbidity index  \
# 0    091 101 Vironniemen peruspiiri                   67.586539
# 1                091 10 Kruununhaka                   67.586539
# 2                     091 20 Kluuvi                   67.586539
# 3                091 80 Katajanokka                   67.586539
# 4    091 102 Ullanlinnan peruspiiri                   65.665101
# 5            091 30 Kaartinkaupunki                   65.665101
# 6                  091 50 Punavuori                   65.665101
# 7                       091 60 Eira                   65.665101
# 8                 091 70 Ullanlinna                   65.665101
# 9                091 90 Kaivopuisto                   65.665101
# 10               091 204 Hernesaari                   65.665101
# 11              091 520 Suomenlinna                   65.665101
# 12              091 531 Länsisaaret                   65.665101
# 13  091 103 Kampinmalmin peruspiiri                   82.818148
# 14                    091 40 Kamppi                   82.818148
# 15                091 130 Etu-Töölö                   82.818148
# 16               091 201 Ruoholahti                   82.818148
# 17               091 202 Lapinlahti                   82.818148
# 18               091 203 Jätkäsaari                   82.818148
# 19   091 104 Taka-Töölön peruspiiri                   87.902482
#     Morbidity, Medicine reimbursement index  Morbidity, Chronic diseases index
# 0                                 85.867423                          76.318461
# 1                                 85.867423                          76.318461
# 2                                 85.867423                          76.318461
# 3                                 85.867423                          76.318461
# 4                                 80.842549                          67.995023
# 5                                 80.842549                          67.995023
# 6                                 80.842549                          67.995023
# 7                                 80.842549                          67.995023
# 8                                 80.842549                          67.995023
# 9                                 80.842549                          67.995023
# 10                                80.842549                          67.995023
# 11                                80.842549                          67.995023
# 12                                80.842549                          67.995023
# 13                                94.765503                          88.586840
# 14                                94.765503                          88.586840
# 15                                94.765503                          88.586840
# 16                                94.765503                          88.586840
# 17                                94.765503                          88.586840
# 18                                94.765503                          88.586840
# 19                                90.008771                          85.981219
# 20                                90.008771                          85.981219
# 21                                88.849234                          76.159888
# 22                                88.849234                          76.159888
# 23                                88.849234                          76.159888
# 24                                88.849234                          76.159888
# 25                                88.849234                          76.159888
# 26                               102.156851                         100.630765
# 27                               102.156851                         100.630765
# 28                               102.156851                         100.630765
# 29                               102.156851                         100.630765
# 30                               102.156851                         100.630765
# 31                                93.506284                          90.378942
# 32                                93.506284                          90.378942
# 33                                93.506284                          90.378942
# 34                                93.506284                          90.378942
# 35                                93.506284                          90.378942
# 36                                93.506284                          90.378942
# 37                                93.506284                          90.378942
# 38                                99.821315                         102.880702
# 39                                99.821315                         102.880702
# 40                                99.821315                         102.880702
# 41                                99.821315                         102.880702
# 42                                99.821315                         102.880702
# 43                                96.350997                         103.612896
# 44                                96.350997                         103.612896
# 45                                96.350997                         103.612896
# 46                                96.350997                         103.612896
# 47                                96.350997                         103.612896
# 48                                96.350997                         103.612896
# 49                                96.350997                         103.612896

# %% [markdown]
# ## Merge one-person households and morbidity index with population dataframe

# %%
# Read population data (including district names with and without å, ä, ö)
population_df2 = pd.read_csv('../data/population_df2.csv')

# Change gender to categorical type
population_df2['Gender'] = population_df2['Gender'].astype('category')

population_df2
# Out:
#     Gender  \
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
# ..     ...
# 363      1
# 364      0
# 365      1
# 366      0
# 367      1
#
#      Education % 15-24 years Second degree and special vocational training degree  \
# 0                                             0.059870
# 1                                             0.079023
# 2                                             0.058338
# 3                                             0.088615
# 4                                             0.056744
# ..                                                 ...
# 363                                           0.046091
# 364                                           0.068623
# 365                                           0.088223
# 366                                           0.039430
# 367                                           0.086763
#
#      Education % 15-24 years Lowest higher and lower university level  \
# 0                                             0.008553
# 1                                             0.016667
# 2                                             0.007025
# 3                                             0.018624
# 4                                             0.008216
# ..                                                 ...
# 363                                           0.006647
# 364                                           0.009455
# 365                                           0.017459
# 366                                           0.002767
# 367                                           0.011123
#
#      Education % 15-24 years Higher university degree and research training  \
# 0                                             0.000342
# 1                                             0.000575
# 2                                             0.000000
# 3                                             0.001502
# 4                                             0.000382
# ..                                                 ...
# 363                                           0.000399
# 364                                           0.000423
# 365                                           0.001057
# 366                                           0.000000
# 367                                           0.000000
#
#      Education % 15-24 years All levels of education  \
# 0                                           0.116319
# 1                                           0.145402
# 1                091 10 Kruununhaka              091 10 Kruununhaka
# 2               091 101 Vilhonvuori             091 101 Vilhonvuori
# 3               091 101 Vilhonvuori             091 101 Vilhonvuori
# 4    091 101 Vironniemen peruspiiri  091 101 Vironniemen peruspiiri
# ..                              ...                             ...
# 363            091 997 Esikaupungit            091 997 Esikaupungit
# 364           091 998 Kantakaupunki           091 998 Kantakaupunki
# 365           091 998 Kantakaupunki           091 998 Kantakaupunki
# 366                    091 999 Muut                    091 999 Muut
# 367                    091 999 Muut                    091 999 Muut
#
# [368 rows x 45 columns]

# %%
# Merge one-person households with population data
population_df3 = pd.merge(left=population_df2, right=ones_portions, how='left', on=['Gender', 'Area'])

# Merge morbidity index 
population_df3 = pd.merge(left=population_df3, right=morb, how='left', on='Area')
# Replace filled morbidity data with NaN for areas where population is too few to be included
morb_cols = morb.columns.drop('Area')
for col in morb_cols:
    population_df3[col] = population_df3.apply(lambda x: np.nan if pd.isna(x['One-person hh, All ages, %']) 
                                               else x[col], axis=1)

population_df3
# Out:
#     Gender  \
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
# ..     ...
# 363      1
# 364      0
# 365      1
# 366      0
# 367      1
#
#      Education % 15-24 years Second degree and special vocational training degree  \
# 0                                             0.059870
# 1                                             0.079023
# 2                                             0.058338
# 3                                             0.088615
# 4                                             0.056744
# ..                                                 ...
# 363                                           0.046091
# 364                                           0.068623
# 365                                           0.088223
# 366                                           0.039430
# 367                                           0.086763
#
#      Education % 15-24 years Lowest higher and lower university level  \
# 0                                             0.008553
# 1                                             0.016667
# 2                                             0.007025
# 3                                             0.018624
# 4                                             0.008216
# ..                                                 ...
# 363                                           0.006647
# 364                                           0.009455
# 365                                           0.017459
# 366                                           0.002767
# 367                                           0.011123
#
#      Education % 15-24 years Higher university degree and research training  \
# 0                                             0.000342
# 1                                             0.000575
# 2                                             0.000000
# 3                                             0.001502
# 4                                             0.000382
# ..                                                 ...
# 363                                           0.000399
# 364                                           0.000423
# 365                                           0.001057
# 366                                           0.000000
# 367                                           0.000000
#
#      Education % 15-24 years All levels of education  \
# 0                                           0.116319
# 1                                           0.145402
# 2                                           0.100794
# 3                                           0.143286
# 4                                           0.115017
# ..                                               ...
# 363                                         0.113049
# 364                                         0.122246
# 365                                         0.147080
# 366                                         0.142225
# 367                                         0.212681
#
#      Education % 15-24 years Elementary or unknown  \
# 0                                         0.047554
# 1                                         0.049138
# 2                                         0.035431
# 3                                         0.034545
# 4                                         0.049675
# ..                                             ...
# 363                                       0.059912
# 364                                       0.043744
# 365                                       0.040342
# 366                                       0.100028
# 367                                       0.114794
#
#      Education % 15-24 years Total graduates  \
# 0                                   0.068765
# 1                                   0.096264
# 2                                   0.065363
# 3                                   0.108741
# 4                                   0.065342
# ..                                       ...
# 363                                 0.053136
# 364                                 0.078502
# 365                                 0.106738
# 366                                 0.042197
# 367                                 0.097887
#
#      Education % 25-44 years Second degree and special vocational training degree  \
# 0                                             0.105371
# 1                                             0.074138
# 2                                             0.168601
# 3                                             0.123160
# 4                                             0.107375
# ..                                                 ...
# 363                                           0.101443
# 364                                           0.148989
# 365                                           0.100800
# 366                                           0.148727
# 367                                           0.113459
#
#      Education % 25-44 years Lowest higher and lower university level  \
# 0                                             0.083134
# 1                                             0.103736
# 2                                             0.136225
# 3                                             0.141484
# 4                                             0.081582
# ..                                                 ...
# 363                                           0.095361
# 364                                           0.112253
# 365                                           0.129216
# 366                                           0.036386
# 367                                           0.066741
#
#      Education % 25-44 years Higher university degree and research training  \
# 0                                             0.157030
# 1                                             0.157471
# 2                                             0.140195
# 3                                             0.147792
# 4                                             0.138135
# ..                                                 ...
# 363                                           0.100946
# 364                                           0.144381
# 365                                           0.164055
# 366                                           0.039568
# 367                                           0.084538
#
#      ...  One-person hh, Age 65-69, %  One-person hh, Age 70-74, %  \
# 0    ...                     0.011049                     0.012533
# 1    ...                     0.022977                     0.025145
# 2    ...                     0.015407                     0.012552
# 3    ...                     0.023286                     0.024842
# 4    ...                     0.011049                     0.012533
# ..   ...                          ...                          ...
# 363  ...                          NaN                          NaN
# 364  ...                          NaN                          NaN
# 365  ...                          NaN                          NaN
# 366  ...                          NaN                          NaN
# 367  ...                          NaN                          NaN
#
#      One-person hh, Age 75-79, %  One-person hh, Age 80-84, %  \
# 0                       0.008740                     0.007091
# 1                       0.024277                     0.019509
# 2                       0.008150                     0.004640
# 3                       0.019840                     0.014227
# 4                       0.008740                     0.007091
# ..                           ...                          ...
# 363                          NaN                          NaN
# 364                          NaN                          NaN
# 365                          NaN                          NaN
# 366                          NaN                          NaN
# 367                          NaN                          NaN
#
#      One-person hh, Age 85, %  Morbidity, Morbidity index  \
# 0                    0.003793                   67.586539
# 1                    0.017341                   67.586539
# 2                    0.003391                  106.524701
# 3                    0.014227                  106.524701
# 4                    0.003793                   67.586539
# ..                        ...                         ...
# 363                       NaN                         NaN
# 364                       NaN                         NaN
# 365                       NaN                         NaN
# 366                       NaN                         NaN
# 367                       NaN                         NaN
#
#      Morbidity, Mortality index  Morbidity, Disability pension index  \
# 0                     69.787493                             47.10470
# 1                     69.787493                             47.10470
# 2                    108.962657                            110.65974
# 3                    108.962657                            110.65974
# 4                     69.787493                             47.10470
# ..                          ...                                  ...
# 363                         NaN                                  NaN
# 364                         NaN                                  NaN
# 365                         NaN                                  NaN
# 366                         NaN                                  NaN
# 367                         NaN                                  NaN
#
#      Morbidity, Medicine reimbursement index  \
# 0                                  85.867423
# 1                                  85.867423
# 2                                  99.951705
# 3                                  99.951705
# 4                                  85.867423
# ..                                       ...
# 363                                      NaN
# 364                                      NaN
# 365                                      NaN
# 366                                      NaN
# 367                                      NaN
#
#      Morbidity, Chronic diseases index
# 0                            76.318461
# 1                            76.318461
# 2                           105.484865
# 3                           105.484865
# 4                            76.318461
# ..                                 ...
# 363                                NaN
# 364                                NaN
# 365                                NaN
# 366                                NaN
# 367                                NaN
#
# [368 rows x 62 columns]

# %%
# Save to file population_df3.csv
population_df3.to_csv('../data/population_df3.csv', index=False)
